# %% [markdown]
# # MatPlotLib

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.7.1

# %% [markdown]
# #### Using {Matplotlib.pyplot + numpy}

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Plotting x, y

# %%
x = np.array([3, 6])
y = np.array([0, 10])

plt.plot(x, y)

plt.show()

# %% [markdown]
# ### Plotting multiple data points

# %%
x = np.array([0, 1, 2, 3, 4])
y = np.array([5, 10, 0, 50, 20])

plt.plot(x, y)

plt.show()

# %% [markdown]
# ### Plotting multiple lines

# %%
y1 = np.array([1, 3, 1, 7])
y2 = np.array([3, 1, 7, 1])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %% [markdown]
# ### Default X-Points

# %%
y = np.array([10, 6, 7, 1, 9])

plt.plot(y)

plt.show()

# %% [markdown]
# ### Plotting x, y dots

# %%
x = np.array([3, 6])
y = np.array([0, 10])

plt.plot(x, y, 'o')

plt.show()

# %% [markdown]
# ## Using Markers

# %% [markdown]
# <br>'o' = Circle
# <br>'*' = Star
# <br>'.' = point
# <br>
# <br>'+' = Plus
# <br>'P' = {filled} Plus
# <br>'x' = X
# <br>'X' = {filled} X
# <br>'d' = Diamond
# <br>'D' = {bold} Diamond
# <br>'h' = Hexagon
# <br>'H' = {bold} Hexagon
# <br>
# <br>'s' = Square
# <br>'p' = Pentagon
# <br>
# <br>'v' = Triangle Down
# <br>'^' = Triangle Up
# <br>'<' = Triangle Left
# <br>'>' = Triangle Right

# %%
y = np.array([1, 11, 3, 13, 5, 15])

plt.plot(y, marker = 'D')

plt.show()

# %% [markdown]
# ### Maker Size + color

# %%
y = np.array([1, 11, 3, 13, 5, 15])

plt.plot(y, marker='D', ms = 15, mec = 'm', mfc = 'w')

plt.show()

# %% [markdown]
# ## Line Style + Size + Color

# %%
y = np.array([1, 11, 3, 13, 5, 15])

plt.plot(y, linestyle = "dotted", color = "black", linewidth = '5')

plt.show()

# %% [markdown]
# ## Using FMT

# %% [markdown]
# <h5>Line Reference</h5>
# '-'  = Solid line
# <br>':'  = Dotted line
# <br>'--' = Dashed line
# <br>'-.' = Dashed/dotted line
#
# <h5>Color Reference</h5>
# 'r' = Red
# <br>'g' = Green
# <br>'b' = Blue
# <br>'c' = Cyan
# <br>'m' = Magenta
# <br>'y' = Yellow
# <br>'k' = Black
# <br>'w' = White

# %%
y = np.array([1, 11, 3, 13, 5, 15])

plt.plot(y, 'D-.b')

plt.show()

# %% [markdown]
# ## Labels

# %%
x = np.array([1, 2, 3, 4, 5, 6])
y = np.array([1, 11, 3, 13, 5, 15])

plt.plot(x, y)

plt.title("Graph")
plt.xlabel("X -->")
plt.ylabel("Y -->")

plt.show()

# %% [markdown]
# ### Using fonts & Positions

# %%
x = np.array([1, 2, 3, 4, 5, 6])
y = np.array([1, 11, 3, 13, 5, 15])

plt.plot(x, y)

font = {'family': 'Arial', 'color': 'red', 'size': 15}

plt.title("Graph", fontdict= font, loc = 'left')
plt.xlabel("X -->", fontdict= font)
plt.ylabel("Y -->", fontdict=font)

plt.show()

# %% [markdown]
# ## Background

# %% [markdown]
# ### Grid

# %%
x = np.array([1, 2, 3, 4, 5, 6])
y = np.array([1, 11, 3, 13, 5, 15])

plt.plot(x, y)
plt.grid()
plt.show()

# %% [markdown]
# ### Lines

# %%
x = np.array([1, 2, 3, 4, 5, 6])
y = np.array([1, 11, 3, 13, 5, 15])

plt.plot(x, y)
plt.grid(axis = 'x') # Can also use y axis
plt.show()

# %% [markdown]
# ### Styling

# %%
x = np.array([1, 2, 3, 4, 5, 6])
y = np.array([1, 11, 3, 13, 5, 15])

plt.plot(x, y)
plt.grid(color = "blue", linestyle = "--", linewidth = 2)
plt.show()

# %% [markdown]
# ## SubPlot
